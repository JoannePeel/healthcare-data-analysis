# %% [markdown]
# # Description

# %%
# Import dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Read csv file and load to a Pandas DataFrame
hospital_data_to_load = "hospitals.csv"
hospitals = pd.read_csv(hospital_data_to_load, encoding='latin-1')

# %%
# Pandas DataFrame preview
hospitals.tail()
# Out:
#              CLUES NOMBRE DE LA ENTIDAD  CLAVE DE LA ENTIDAD  \
# 38990  ZSSSA013172            ZACATECAS                   32
# 38991  ZSSSA013184            ZACATECAS                   32
# 38992  ZSSSA013196            ZACATECAS                   32
# 38993  ZSSSA013201            ZACATECAS                   32
# 38994  ZSSSA013213            ZACATECAS                   32
#
#       NOMBRE DEL MUNICIPIO  CLAVE DEL MUNICIPIO NOMBRE DE LA LOCALIDAD  \
# 38990            GUADALUPE                   17              GUADALUPE
# 38991            GUADALUPE                   17              GUADALUPE
# 38992            FRESNILLO                   10              FRESNILLO
# 38993                PINOS                   38                  PINOS
# 38994           RÍO GRANDE                   39             RIO GRANDE
#
#        CLAVE DE LA LOCALIDAD NOMBRE DE LA JURISDICCION  \
# 38990                      1                 ZACATECAS
# 38991                      1                 ZACATECAS
# 38992                      1                 FRESNILLO
# 38993                      1               OJOCALIENTE
# 38994                      1                RÍO GRANDE
#
#        CLAVE DE LA JURISDICCION NOMBRE DE LA INSTITUCION  \
# 38990                         1      SECRETARIA DE SALUD
# 38991                         1      SECRETARIA DE SALUD
# 38992                         3      SECRETARIA DE SALUD
# 38993                         2      SECRETARIA DE SALUD
# 38994                         4      SECRETARIA DE SALUD
#
#                ...           CLAVE ESTRATO UNIDAD        TIPO OBRA  \
# 38990          ...                            2.0  NO ESPECIFICADO
# 38991          ...                            2.0  NO ESPECIFICADO
# 38992          ...                            2.0  NO ESPECIFICADO
# 38993          ...                            2.0  NO ESPECIFICADO
# 38994          ...                            2.0  NO ESPECIFICADO
#
#       CLAVE TIPO OBRA  HORARIO DE ATENCION  \
# 38990             6.0                  NaN
# 38991             6.0                  NaN
# 38992             6.0                  NaN
# 38993             6.0                  NaN
# 38994             6.0                  NaN
#
#                                        AREAS Y SERVICIOS ULTIMO MOVIMIENTO  \
# 38990  MEDICINA GENERAL - CONSULTA EXTERNA BÁSICA | U...              ALTA
# 38991                                                NaN              ALTA
# 38992  ESTOMATOLOGIA - CONSULTA EXTERNA BÁSICA | PLAN...              ALTA
# 38993  ESTOMATOLOGIA - CONSULTA EXTERNA BÁSICA | URGE...              ALTA
# 38994  MEDICINA GENERAL - CONSULTA EXTERNA BÁSICA | P...              ALTA
#
#       FECHA ULTIMO MOVIMIENTO CERTIFICACION CSG  TIPO CERTIFICACION  \
# 38990              2011-10-06    NO CERTIFICADO     NO ESPECIFICADO
# 38991              2011-10-06    NO CERTIFICADO     NO ESPECIFICADO
# 38992              2011-11-18    NO CERTIFICADO     NO ESPECIFICADO
# 38993              2012-09-27    NO CERTIFICADO     NO ESPECIFICADO
# 38994              2012-12-06    NO CERTIFICADO     NO ESPECIFICADO
#
#       VIGENCIA CERTIFICACION
# 38990                    NaN
# 38991                    NaN
# 38992                    NaN
# 38993                    NaN
# 38994                    NaN
#
# [5 rows x 80 columns]

# %%
# Pandas DataFrame filtering information for "Nombre de la Entidad = Ciudad de Mexico"
hospitals_cdmx1 = hospitals.loc[(hospitals["NOMBRE DE LA ENTIDAD"] == "CIUDAD DE MEXICO")]
hospitals_cdmx1.head()
# Out:
#             CLUES NOMBRE DE LA ENTIDAD  CLAVE DE LA ENTIDAD  \
# 6393  DFCIJ000011     CIUDAD DE MEXICO                    9
# 6394  DFCIJ000023     CIUDAD DE MEXICO                    9
# 6395  DFCIJ000035     CIUDAD DE MEXICO                    9
# 6396  DFCIJ000040     CIUDAD DE MEXICO                    9
# 6397  DFCIJ000052     CIUDAD DE MEXICO                    9
#
#        NOMBRE DEL MUNICIPIO  CLAVE DEL MUNICIPIO NOMBRE DE LA LOCALIDAD  \
# 6393    VENUSTIANO CARRANZA                   17    VENUSTIANO CARRANZA
# 6394             CUAUHTÉMOC                   15        NO ESPECIFICADO
# 6395  CUAJIMALPA DE MORELOS                    4  CUAJIMALPA DE MORELOS
# 6396               COYOACÁN                    3               COYOACAN
# 6397          BENITO JUÁREZ                   14          BENITO JUAREZ
#
#       CLAVE DE LA LOCALIDAD NOMBRE DE LA JURISDICCION  \
# 6393                      1       VENUSTIANO CARRANZA
# 6394                   9999                CUAUHTÉMOC
# 6395                      1                CUAJIMALPA
# 6396                      1                  COYOACÁN
# 6397                      1             BENITO JUÁREZ
#
#       CLAVE DE LA JURISDICCION        NOMBRE DE LA INSTITUCION  \
# 6393                        16  CENTROS DE INTEGRACION JUVENIL
# 6394                        15  CENTROS DE INTEGRACION JUVENIL
# 6395                         7  CENTROS DE INTEGRACION JUVENIL
# 6396                         4  CENTROS DE INTEGRACION JUVENIL
# 6397                        14  CENTROS DE INTEGRACION JUVENIL
#
#               ...           CLAVE ESTRATO UNIDAD        TIPO OBRA  \
# 6393          ...                            2.0  NO ESPECIFICADO
# 6394          ...                            2.0  NO ESPECIFICADO
# 6395          ...                            2.0  NO ESPECIFICADO
# 6396          ...                            2.0  NO ESPECIFICADO
# 6397          ...                            2.0  NO ESPECIFICADO
#
#      CLAVE TIPO OBRA                                HORARIO DE ATENCION  \
# 6393             6.0  CONSULTA EXTERNA - L,M,X,J,V, DE 08:00:00 A 20...
# 6394             6.0  CONSULTA EXTERNA - L,M,X,J,V, DE 08:00:00 A 19...
# 6395             6.0  CONSULTA EXTERNA - L,M,X,J,V, DE 08:00:00 A 16...
# 6396             6.0  CONSULTA EXTERNA - L,M,X,J,V, DE 08:00:00 A 20...
# 6397             6.0  CONSULTA EXTERNA - L,M,X,J,V, DE 08:00:00 A 19...
#
#      AREAS Y SERVICIOS ULTIMO MOVIMIENTO FECHA ULTIMO MOVIMIENTO  \
# 6393               NaN              ALTA              2018-10-16
# 6394               NaN              ALTA              2018-10-16
# 6395               NaN              ALTA              2018-10-16
# 6396               NaN              ALTA              2018-10-16
# 6397               NaN              ALTA              2018-10-16
#
#      CERTIFICACION CSG  TIPO CERTIFICACION VIGENCIA CERTIFICACION
# 6393    NO CERTIFICADO     NO ESPECIFICADO                    NaN
# 6394    NO CERTIFICADO     NO ESPECIFICADO                    NaN
# 6395    NO CERTIFICADO     NO ESPECIFICADO                    NaN
# 6396    NO CERTIFICADO     NO ESPECIFICADO                    NaN
# 6397    NO CERTIFICADO     NO ESPECIFICADO                    NaN
#
# [5 rows x 80 columns]

# %%
# Pandas DataFrame filtering information for "Nombre Tipo Establecimiento = De Hospitalización"
hospitals_cdmx = hospitals_cdmx1.loc[(hospitals_cdmx1["NOMBRE TIPO ESTABLECIMIENTO"] == "DE HOSPITALIZACIÓN")]
hospitals_cdmx.head()

# Pandas DataFrame column info
hospitals_cdmx.columns
# Out:
# Index(['CLUES', 'NOMBRE DE LA ENTIDAD', 'CLAVE DE LA ENTIDAD',
#        'NOMBRE DEL MUNICIPIO', 'CLAVE DEL MUNICIPIO', 'NOMBRE DE LA LOCALIDAD',
#        'CLAVE DE LA LOCALIDAD', 'NOMBRE DE LA JURISDICCION',
#        'CLAVE DE LA JURISDICCION', 'NOMBRE DE LA INSTITUCION',
#        'CLAVE DE LA INSTITUCION', 'CLAVE CORTA DE LA INSTITUCION',
#        'NOMBRE TIPO ESTABLECIMIENTO', 'CLAVE TIPO ESTABLECIMIENTO',
#        'NOMBRE DE TIPOLOGIA', 'CLAVE DE TIPOLOGIA', 'NOMBRE DE SUBTIPOLOGIA',
#        'CLAVE DE SUBTIPOLOGIA', 'CLAVE SCIAN', 'DESCRIPCION CLAVE SCIAN',
#        'CONSULTORIOS DE MED GRAL', 'CONSULTORIOS EN OTRAS AREAS',
#        'TOTAL DE CONSULTORIOS', 'CAMAS EN AREA DE HOS', 'CAMAS EN OTRAS AREAS',
#        'TOTAL DE CAMAS', 'NOMBRE DE LA UNIDAD', 'CLAVE DE VIALIDAD',
#        'TIPO DE VIALIDAD', 'VIALIDAD', 'NUMERO EXTERIOR', 'NUMERO INTERIOR',
#        'CLAVE DEL TIPO DE ASENTAMIENTO', 'TIPO DE ASENTAMIENTO',
#        'ASENTAMIENTO', 'ENTRE TIPO DE VIALIDAD 1', 'ENTRE VIALIDAD 1',
#        'ENTRE TIPO DE VIALIDAD 2', 'ENTRE VIALIDAD 2',
#        'OBSERVACIONES DE LA DIRECCION', 'CODIGO POSTAL',
#        'ESTATUS DE OPERACION', 'CLAVE DE ESTATUS DE OPERACION',
#        'TIENE LICENCIA SANITARIA', 'NUMERO DE LICENCIA SANITARIA',
#        'TIENE AVISO DE FUNCIONAMIENTO', 'FECHA EMISION AV. FUN.',
#        'RFC DEL ESTABLECIMIENTO', 'FECHA DE CONSTRUCCION',
#        'FECHA DE INICIO DE OPERACION', 'UNIDAD MOVIL MARCA',
#        'UNIDAD MOVIL MODELO', 'UNIDAD MOVIL CAPACIDAD',
#        'UNIDAD MOVIL PROGRAMA', 'UNIDAD MOVIL CLAVE PROGRAMA',
#        'UNIDAD MOVIL TIPO', 'UNIDAD MOVIL CLAVE TIPO',
#        'UNIDAD MOVIL TIPOLOGIA', 'UNIDAD MOVIL CLAVE TIPOLOGIA', 'LONGITUD',
#        'LATITUD', 'NOMBRE DE LA INS ADM', 'CLAVE DE LA INS ADM',
#        'NIVEL ATENCION', 'CLAVE NIVEL ATENCION', 'ESTATUS ACREDITACION',
#        'CLAVE ESTATUS ACREDITACION', 'ACREDITACIONES', 'SUBACREDITACION',
#        'ESTRATO UNIDAD', 'CLAVE ESTRATO UNIDAD', 'TIPO OBRA',
#        'CLAVE TIPO OBRA', 'HORARIO DE ATENCION', 'AREAS Y SERVICIOS',
#        'ULTIMO MOVIMIENTO', 'FECHA ULTIMO MOVIMIENTO', 'CERTIFICACION CSG',
#        'TIPO CERTIFICACION', 'VIGENCIA CERTIFICACION'],
#       dtype='object')

# %%
# Pandas DataFrame creation just with the column info that we need 
cdmx_hospitals = hospitals_cdmx[['CLUES', 'NOMBRE DE LA ENTIDAD', 'NOMBRE DEL MUNICIPIO', 'NOMBRE DE LA LOCALIDAD',
       'NOMBRE DE LA JURISDICCION', 'CLAVE DE LA INSTITUCION', 'NOMBRE DE TIPOLOGIA', 'CONSULTORIOS DE MED GRAL', 'CONSULTORIOS EN OTRAS AREAS',
       'TOTAL DE CONSULTORIOS', 'CAMAS EN AREA DE HOS', 'CAMAS EN OTRAS AREAS',
       'TOTAL DE CAMAS', 'NOMBRE DE LA UNIDAD', 'OBSERVACIONES DE LA DIRECCION', 'CODIGO POSTAL',
       'ESTATUS DE OPERACION', 'LONGITUD', 'LATITUD', 'NIVEL ATENCION']]
cdmx_hospitals.head()      
cdmx_hospitals.columns
# Out:
# Index(['CLUES', 'NOMBRE DE LA ENTIDAD', 'NOMBRE DEL MUNICIPIO',
#        'NOMBRE DE LA LOCALIDAD', 'NOMBRE DE LA JURISDICCION',
#        'CLAVE DE LA INSTITUCION', 'NOMBRE DE TIPOLOGIA',
#        'CONSULTORIOS DE MED GRAL', 'CONSULTORIOS EN OTRAS AREAS',
#        'TOTAL DE CONSULTORIOS', 'CAMAS EN AREA DE HOS', 'CAMAS EN OTRAS AREAS',
#        'TOTAL DE CAMAS', 'NOMBRE DE LA UNIDAD',
#        'OBSERVACIONES DE LA DIRECCION', 'CODIGO POSTAL',
#        'ESTATUS DE OPERACION', 'LONGITUD', 'LATITUD', 'NIVEL ATENCION'],
#       dtype='object')

# %%
# Pandas DataFrame filtering information for "Estatus de Operación = En Operación"
cdmx_hospitals = cdmx_hospitals.loc[(cdmx_hospitals["ESTATUS DE OPERACION"] == "EN OPERACION")]

# Pandas DataFrame filtering information for "Total de Camas = 0", because those hospitals has no impact on the analysis
cdmx_hospitals = cdmx_hospitals.loc[(cdmx_hospitals["TOTAL DE CAMAS"] != 0)]
# cdmx_hospitals.head()

# %%
cdmx_hospitals.to_csv('cdmx_hospitals.csv')

# %%
cdmx_hospitals_file = "cdmx_hospitals.csv"

cdmx_hospitals_df = pd.read_csv(cdmx_hospitals_file)
cdmx_hospitals_df.head()
# Out:
#    Unnamed: 0        CLUES NOMBRE DE LA ENTIDAD NOMBRE DEL MUNICIPIO  \
# 0        6399  DFCRO000011     CIUDAD DE MEXICO       MIGUEL HIDALGO
# 1        6505  DFIMS000020     CIUDAD DE MEXICO         AZCAPOTZALCO
# 2        6507  DFIMS000044     CIUDAD DE MEXICO         AZCAPOTZALCO
# 3        6508  DFIMS000056     CIUDAD DE MEXICO         AZCAPOTZALCO
# 4        6509  DFIMS000061     CIUDAD DE MEXICO         AZCAPOTZALCO
#
#   NOMBRE DE LA LOCALIDAD NOMBRE DE LA JURISDICCION CLAVE DE LA INSTITUCION  \
# 0         MIGUEL HIDALGO            MIGUEL HIDALGO                     CRO
# 1           AZCAPOTZALCO              AZCAPOTZALCO                    IMSS
# 2           AZCAPOTZALCO              AZCAPOTZALCO                    IMSS
# 3           AZCAPOTZALCO              AZCAPOTZALCO                    IMSS
# 4           AZCAPOTZALCO              AZCAPOTZALCO                    IMSS
#
#               NOMBRE DE TIPOLOGIA  CONSULTORIOS DE MED GRAL  \
# 0                 NO ESPECIFICADO                         5
# 1      HOSPITAL DE ESPECIALIDADES                        75
# 2  HOSPITAL DE GINECO-OBSTETRICIA                        31
# 3           HOSPITAL INFECTOLOGÍA                         6
# 4                HOSPITAL GENERAL                        69
#
#    CONSULTORIOS EN OTRAS AREAS       ...        CAMAS EN AREA DE HOS  \
# 0                            0       ...                          60
# 1                            0       ...                         465
# 2                            0       ...                         306
# 3                            0       ...                         148
# 4                            0       ...                         523
#
#    CAMAS EN OTRAS AREAS  TOTAL DE CAMAS  \
# 0                     0              60
# 1                     0             465
# 2                     0             306
# 3                     0             148
# 4                     0             523
#
#                                  NOMBRE DE LA UNIDAD  \
# 0  CENTRO DE TRAUMA DE CRUZ ROJA MEXICANA EN EL D...
# 1                                     HES CM LA RAZA
# 2                                     HGO CM LA RAZA
# 3                                  HINFEC CM LA RAZA
# 4                                      HG CM LA RAZA
#
#                        OBSERVACIONES DE LA DIRECCION CODIGO POSTAL  \
# 0  AV. EJÉRCITO NACIONAL NO. 1032, COLONIA LOS MO...       11510.0
# 1  SERIS Y ZAACHILA  COL. LA RAZA C.P. 02990, AZC...        2990.0
# 2  CLZD. VALLEJO ESQ. ANTONIO VALERIANO  COL. LA ...        2990.0
# 3  ZAACHILA Y JACARANDAS S/N  COL. LA RAZA C.P. 0...        2990.0
# 4  CLZD. VALLEJO Y JACARANDAS  COL. LA RAZA C.P. ...        2990.0
#
#    ESTATUS DE OPERACION     LONGITUD    LATITUD  NIVEL ATENCION
# 0          EN OPERACION  -99.2088913  19.438531   SEGUNDO NIVEL
# 1          EN OPERACION     -99.1442  19.466200    TERCER NIVEL
# 2          EN OPERACION  -99.1470262  19.466440   SEGUNDO NIVEL
# 3          EN OPERACION   -99.144716  19.466279    TERCER NIVEL
# 4          EN OPERACION      -99.182  19.486000   SEGUNDO NIVEL
#
# [5 rows x 21 columns]

# %%
#How many beds are in CDMX
total_beds_cdmx = cdmx_hospitals_df["TOTAL DE CAMAS"].sum()

#Group info by delegation 
cdmx_by_delegation = cdmx_hospitals_df.groupby(['NOMBRE DEL MUNICIPIO'])

#How many beds are in CDMX by delegation
total_beds_by_delegation = cdmx_by_delegation["TOTAL DE CAMAS"].sum()

# Place total_beds_by_delegation dataseries into in a Pandas DataFrame
total_df_beds = pd.DataFrame(data=total_beds_by_delegation)

#How many hospitals are in CDMX by delegation
total_hospitals_by_delegation = cdmx_by_delegation["NOMBRE DE LA UNIDAD"].nunique()

# Place total_hospitals_by_delegation dataseries into a Pandas DataFrame
total_df_hospitals = pd.DataFrame(data = total_hospitals_by_delegation)
total_df_hospitals

total_df_beds['TOTAL DE HOSPITALES'] = total_df_hospitals
total_df_beds
# Out:
#                         TOTAL DE CAMAS  TOTAL DE HOSPITALES
# NOMBRE DEL MUNICIPIO
# AZCAPOTZALCO                      1910                   21
# BENITO JUÁREZ                     1631                   28
# COYOACÁN                          1073                   26
# CUAJIMALPA DE MORELOS               24                    6
# CUAUHTÉMOC                        3735                   52
# GUSTAVO A. MADERO                 2916                   92
# IZTACALCO                          623                   22
# IZTAPALAPA                        2065                  117
# LA MAGDALENA CONTRERAS              72                    5
# MIGUEL HIDALGO                    2723                   35
# MILPA ALTA                         133                   12
# TLALPAN                           2364                   33
# TLÁHUAC                            497                   32
# VENUSTIANO CARRANZA                619                   27
# XOCHIMILCO                         216                   25
# ÁLVARO OBREGÓN                    1548                   22

# %%
population_file = "population_cdmx.csv"

cdmx_population_df = pd.read_csv(population_file)
cdmx_population_df = cdmx_population_df.rename(columns={'Delegación': 'NOMBRE DEL MUNICIPIO', 'Total': 'TOTAL DE HABITANTES'})

cdmx_population_df.set_index('NOMBRE DEL MUNICIPIO', inplace=True) 
cdmx_population_df

total_df_beds = total_df_beds.join(cdmx_population_df, how="outer")
total_df_beds
# Out:
#                         TOTAL DE CAMAS  TOTAL DE HOSPITALES  \
# NOMBRE DEL MUNICIPIO
# AZCAPOTZALCO                      1910                   21
# BENITO JUÁREZ                     1631                   28
# COYOACÁN                          1073                   26
# CUAJIMALPA DE MORELOS               24                    6
# CUAUHTÉMOC                        3735                   52
# GUSTAVO A. MADERO                 2916                   92
# IZTACALCO                          623                   22
# IZTAPALAPA                        2065                  117
# LA MAGDALENA CONTRERAS              72                    5
# MIGUEL HIDALGO                    2723                   35
# MILPA ALTA                         133                   12
# TLALPAN                           2364                   33
# TLÁHUAC                            497                   32
# VENUSTIANO CARRANZA                619                   27
# XOCHIMILCO                         216                   25
# ÁLVARO OBREGÓN                    1548                   22
#
#                         TOTAL DE HABITANTES
# NOMBRE DEL MUNICIPIO
# AZCAPOTZALCO                         414711
# BENITO JUÁREZ                        385439
# COYOACÁN                             620416
# CUAJIMALPA DE MORELOS                186391
# CUAUHTÉMOC                           531831
# GUSTAVO A. MADERO                   1185772
# IZTACALCO                            384326
# IZTAPALAPA                          1815786
# LA MAGDALENA CONTRERAS               239086
# MIGUEL HIDALGO                       372889
# MILPA ALTA                           130582
# TLALPAN                              360265
# TLÁHUAC                              650567
# VENUSTIANO CARRANZA                  430978
# XOCHIMILCO                           415007
# ÁLVARO OBREGÓN                       727034

# %%
total_df_beds['BEDS PER 100'] = total_df_beds['TOTAL DE CAMAS']/total_df_beds['TOTAL DE HABITANTES']*1000

total_df_beds['BEDS PER 100'] = total_df_beds['BEDS PER 100'].map("{:,.2f}".format)
total_df_beds
# Out:
#                         TOTAL DE CAMAS  TOTAL DE HOSPITALES  \
# NOMBRE DEL MUNICIPIO
# AZCAPOTZALCO                      1910                   21
# BENITO JUÁREZ                     1631                   28
# COYOACÁN                          1073                   26
# CUAJIMALPA DE MORELOS               24                    6
# CUAUHTÉMOC                        3735                   52
# GUSTAVO A. MADERO                 2916                   92
# IZTACALCO                          623                   22
# IZTAPALAPA                        2065                  117
# LA MAGDALENA CONTRERAS              72                    5
# MIGUEL HIDALGO                    2723                   35
# MILPA ALTA                         133                   12
# TLALPAN                           2364                   33
# TLÁHUAC                            497                   32
# VENUSTIANO CARRANZA                619                   27
# XOCHIMILCO                         216                   25
# ÁLVARO OBREGÓN                    1548                   22
#
#                         TOTAL DE HABITANTES BEDS PER 100
# NOMBRE DEL MUNICIPIO
# AZCAPOTZALCO                         414711         4.61
# BENITO JUÁREZ                        385439         4.23
# COYOACÁN                             620416         1.73
# CUAJIMALPA DE MORELOS                186391         0.13
# CUAUHTÉMOC                           531831         7.02
# GUSTAVO A. MADERO                   1185772         2.46
# IZTACALCO                            384326         1.62
# IZTAPALAPA                          1815786         1.14
# LA MAGDALENA CONTRERAS               239086         0.30
# MIGUEL HIDALGO                       372889         7.30
# MILPA ALTA                           130582         1.02
# TLALPAN                              360265         6.56
# TLÁHUAC                              650567         0.76
# VENUSTIANO CARRANZA                  430978         1.44
# XOCHIMILCO                           415007         0.52
# ÁLVARO OBREGÓN                       727034         2.13

# %%
total_df_beds = total_df_beds.sort_values("TOTAL DE CAMAS", ascending=True)
total_df_beds['TOTAL DE CAMAS'].plot(kind="barh", figsize=(12,8), legend = False, facecolor = 'blue')
plt.title("Number of beds by delegation").set_size(20)
plt.xlabel("Number of beds").set_size(20)
plt.ylabel("Delegation").set_size(20)
plt.tick_params(axis="x", labelsize=14) 
plt.tick_params(axis="y", labelsize=14)
plt.savefig("number_of_bed_by_delegation.png")
plt.show()

# %%
total_df_beds = total_df_beds.sort_values("TOTAL DE HOSPITALES", ascending=True)
total_df_beds['TOTAL DE HOSPITALES'].plot(kind="barh", figsize=(12,8), legend = False, facecolor = 'lightblue')
plt.title("Number of hospitals by delegation").set_size(20)
plt.xlabel("Number of hospitals").set_size(20)
plt.ylabel("Delegation").set_size(20)
plt.tick_params(axis="x", labelsize=14) 
plt.tick_params(axis="y", labelsize=14)
plt.savefig("number_of_hospitals_by_delegation.png")
plt.show()

# %%
total_df_beds = total_df_beds.sort_values("TOTAL DE HABITANTES", ascending=True)
total_df_beds['TOTAL DE HABITANTES'].plot(kind="barh", figsize=(12,8), legend = False, facecolor = 'green')
plt.title("Total population by delegation").set_size(20)
plt.xlabel("Population").set_size(20)
plt.ylabel("Delegation").set_size(20)
plt.tick_params(axis="x", labelsize=14) 
plt.tick_params(axis="y", labelsize=14)
plt.savefig("Total_population_by_delegation.png")
plt.show()

# %%
total_df_beds = total_df_beds.sort_values("BEDS PER 100", ascending=False)
# total_df_beds['BEDS PER 100'].plot(kind="barh", figsize=(12,8), legend = False, facecolor = 'green')
# plt.title("Total population by delegation").set_size(20)
# plt.xlabel("Population").set_size(20)
# plt.ylabel("Delegation").set_size(20)
# plt.tick_params(axis="x", labelsize=14) 
# plt.tick_params(axis="y", labelsize=14)
# plt.savefig("Total_population_by_delegation.png")
# plt.show()
